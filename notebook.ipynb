# %% [markdown]
# # Introduction to Computers

# %% [markdown]
# ## Introduction

# %% [markdown]
# # Steven Moore
# *bad typist*
#
# English Major - Poetry, Writing
#
# Hobby and Profession mixed up
#
# Lockedheed Martin
#
# Web Developer
#
# Teaching CS for many years (2015)
#
# 3 classes per semester

# %% [markdown]
# # Course Topics
#
# * Computer Basics
# * Spreadsheets - kind a prohramming langugae (*Turing Complete*)
#     * Ask that everyone use the university computers
# * Programming Concepts
#     * repl.it
# * Web Programming
#     *

# %% [markdown]
# # Course Breakdown
#
# ## Chapters
#
#     - Reading (reading is for you)
#     - Lectures
#     - Reviews
#     - Exercises (completed in class)
#     - Labs
#     - Exams
#
# **Chapters have due dates**
#
#  Communication goes through Discord - if more than 24 hours (not weekends), please resend
#
#  Course website requires VPN off campus
#  Brightpsace for Grades only
#
#  ### Materials
#  Free online materials - sometimes links go bad, just let me know and I'll fix it

# %% [markdown]
# ## Class
#
# * Short lectures
# * in class exercises
#     * small groups, complete on repl, submit to brightspace
#
# ## Lab
#
# Labs are due on the day of lab
